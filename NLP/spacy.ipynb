# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(
    "The project centers on the development of a decentralized marketplace designed to facilitate secure transacJons between buyers and sellers in a trustless environment. TradiJonal online marketplaces oden rely on centralized intermediaries to manage transacJons and escrow payments, which can introduce delays, increase costs, and create trust issues. To address these challenges, our plaeorm leverages blockchain technology, specifically the Solana blockchain, known for its high throughput and low transacJon fees, to provide a more eﬃcient and secure transacJonal framework."
)

# %%
for i, sentence in enumerate(doc.sents):
    print(i, sentence, end="\n\n")
# Out:
# 0 The project centers on the development of a decentralized marketplace designed to facilitate secure transacJons between buyers and sellers in a trustless environment.
#
# 1 TradiJonal online marketplaces oden rely on centralized intermediaries to manage transacJons and escrow payments, which can introduce delays, increase costs, and create trust issues.
#
# 2 To address these challenges, our plaeorm leverages blockchain technology, specifically the Solana blockchain, known for its high throughput and low transacJon fees, to provide a more eﬃcient and secure transacJonal framework.
